# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn as sl

# %%
# read the data
df = pd.read_csv('../sim_2024-01-08_12-31-41.csv')
df.head()
# Out:
#    tol  L1Size  L2Size  L3Size  L4Size  blkSize  nReqs    reqPatrn  nL1Hits  \
# 0  0.1       0       0       0    2048      256     50  sequential        0
# 1  0.1       0       0     512    2048      256     50  sequential        0
# 2  0.1       0     512       0    2048      256     50  sequential        0
# 3  0.1       0     512     512    2048      256     50  sequential        0
# 4  0.1     512       0       0    2048      256     50  sequential       15
#
#    nL2Hits  ...  anlTime  netLat      q1      q3  median     iqr  lower_bound  \
# 0        0  ...        0       0  0.4246  0.4403  0.4325  0.0157       0.4011
# 1        0  ...        0       0  0.3296  0.5339  0.4951  0.2043       0.0231
# 2       20  ...        0       0  0.2151  0.3136  0.2473  0.0985       0.0673
# 3       20  ...        0       0  0.2348  0.3731  0.3097  0.1383       0.0274
# 4        0  ...        0       0  0.0054  0.4379  0.4311  0.4325      -0.6433
#
#    upper_bound  std_dev  num_gpus
# ...

# %%
# 何を固定してどう見せるかを考えて
# まずは、

# %%
# キャッシュ構成ごとのレイテンシ

# 固定しない変数
cacheArchtecture = None

# 固定する変数
tol = 0.1
UserAnal = 0.2
accessPattern = None


# 縦軸レイテンシー、横軸キャッシュ構成のグラフ
df_comp = df[df["tol"] == 0.1]
df_comp = df_comp.drop(["tol","num_requests","request_pattern","blockSize"],axis=1)

# 縦軸、キャッシュヒット率、横軸キャッシュ構成のグラフ

# 縦軸、平均レイテンシーの内訳の積み上げグラフ、横軸キャッシュ構成のグラフ ()

# %%
# あるキャッシュ構成に対して、キャッシュのサイズを増加させたときのレイテンシ

# 固定しない変数
CacheSize = None

# 固定する変数
cacheArchtecture = None # ここはフォーループを回して一気に行きたいところだね。
tol = 0.1
UserAnal = 0.2
accessPattern = None

# 縦軸レイテンシー、横軸キャッシュ構成のグラフ
df_comp = df[df["tol"] == 0.1]
df_comp = df_comp.drop(["tol","num_requests","request_pattern","blockSize"],axis=1)

# 縦軸、キャッシュヒット率、横軸キャッシュ構成のグラフ

# 縦軸、平均レイテンシーの内訳の積み上げグラフ、横軸キャッシュ構成のグラフ ()

# %%
# すべてのキャッシュ構成に対して、ユーザの処理時間を変化させたときの平均アクセスレイテンシー

# 変動する変数
UserAnal = 0.2

# 固定する変数
cacheArchtecture = None # ここはフォーループを回して一気に行きたいところだね。
tol = 0.1
accessPattern = None

# 縦軸レイテンシー、横軸キャッシュ構成のグラフ
df_comp = df[df["tol"] == 0.1]
df_comp = df_comp.drop(["tol","num_requests","request_pattern","blockSize"],axis=1)

# 縦軸、キャッシュヒット率、横軸キャッシュ構成のグラフ

# 縦軸、平均レイテンシーの内訳の積み上げグラフ、横軸キャッシュ構成のグラフ ()
# Out:
#     L1Size  L2Size  L3Size  L4Size     tatime  numL1Hits  numL2Hits  \
# 0        0       0       0       0  75.206652          0          0
# 1        0       0       0    1024  73.774526          0          0
# 2        0       0       0    2048  73.400184          0          0
# 3        0       0       0    4096  72.650419          0          0
# 4        0       0       0    8192  69.605022          0          0
# 5     1024       0       0       0  53.428474         31          0
# 6     1024       0       0    1024  53.379216         31          0
# 7     1024       0       0    2048  52.785924         31          0
# 8     1024       0       0    4096  51.884563         30          0
# 9     1024       0       0    8192  50.336540         31          0
# 10    2048       0       0       0  50.710146         37          0
# 11    2048       0       0    1024  50.291317         37          0
# 12    2048       0       0    2048  50.143026         37          0
# ...

# %%
# すべてのキャッシュ構成に対して、ユーザの処理時間を変化させたときの平均アクセスレイテンシー

# 変動する変数
tol = 0.1

# 固定する変数
cacheArchtecture = None # ここはフォーループを回して一気に行きたいところだね。
UserAnal = 0.2
accessPattern = None

# 縦軸レイテンシー、横軸キャッシュ構成のグラフ
df_comp = df[df["tol"] == 0.1]
df_comp = df_comp.drop(["tol","num_requests","request_pattern","blockSize"],axis=1)

# 縦軸、キャッシュヒット率、横軸キャッシュ構成のグラフ

# 縦軸、平均レイテンシーの内訳の積み上げグラフ、横軸キャッシュ構成のグラフ ()
